# %%
library(modules)
library(rlang)
load.train <- modules::module({   
    modules::import("magrittr", "%>%") 
    modules::import("dplyr", "select_if", "select", "mutate", "arrange") 
    
    #Loading data functions
    
    train.data <- function() { 
        setwd("C:/Users/iceca/Documents/Housing_Regression")
        load( "Data/RDAs/Train.rda")
        train$isTrain <- NULL
        return(train)
    } 
    test.data <- function() { 
        setwd("C:/Users/iceca/Documents/Housing_Regression")
        load( "Data/RDAs/Test.rda")
        return(test)
    } 
    trim.data <- function() {
        setwd("C:/Users/iceca/Documents/Housing_Regression")
        load( "Data/RDAs/TrimFeatEngTrain.rda")
        load( "Data/RDAs/TrimFeatEngTest.rda")
        return( list(tr, tst) )
    }
    norm.data <- function() {
        setwd("C:/Users/iceca/Documents/Housing_Regression")
        load( "Data/RDAs/NormFeatEngTrain.rda")
        load( "Data/RDAs/NormFeatEngTest.rda")
        return( list(tr, tst) )
    }
    skew.data <- function() {
        setwd("C:/Users/iceca/Documents/Housing_Regression")
        load( "Data/RDAs/FeatEngTrain.rda")
        load( "Data/RDAs/FeatEngTest.rda")
        return( list(tr, tst) )
    }
    no.outliers.data <- function() { 
        setwd("C:/Users/iceca/Documents/Housing_Regression")
        load( "Data/RDAs/TrainNoOutlierRaw.rda")
        train$isTrain <- NULL
        return(train)
    } 
    get.labels <- function() {
        setwd("C:/Users/iceca/Documents/Housing_Regression")
        load( "Data/RDAs/Labels.rda")
        return(labels)
    }
    
    #organizing data frames helpers
    
    nums.data <- function() {
        dat <- train.data()
        dat %>% select_if(is.numeric)
    }
    
    drop.id <- function(dat) {
        dat %>% select(-Id)
    }
    factors.data <- function() {
        dat <- train.data()
        dat %>% select_if(is.factor) %>% mutate(Id = nums.data()$Id)
    }
    nums.data.standardize <- function(dat = nums.data()) {
        drop.id(dat) %>% scale() %>% as.data.frame() %>% mutate(Id = dat$Id)
    }
    combine.columns <- function(l = list(nums.data.standardize() , factors.data() )) {
        dat <- data.frame(Id = l[[1]]$Id)
        for (p in l){
            dat <- cbind(dat %>% arrange(Id),p %>% arrange(Id) %>% select(-Id) )
        }
        dat
    }
    
})
# Out:
# Warning message:
# "package 'modules' was built under R version 3.6.3"Warning message:
# "package 'rlang' was built under R version 3.6.3"

# %%
dat <- load.train$combine.columns(list(load.train$nums.data.standardize(), load.train$factors.data()))

# %%
sapply(dat, levels)
# Out:
# $Id
# NULL
#
# $MSSubClass
# NULL
#
# $LotFrontage
# NULL
#
# $LotArea
# NULL
#
# $OverallQual
# NULL
#
# $OverallCond
# NULL
#
# $YearBuilt
# NULL
#
# $YearRemodAdd
# NULL
#
# $MasVnrArea
# NULL
#
# $BsmtFinSF1
# NULL
#
# $BsmtFinSF2
# NULL
#
# $BsmtUnfSF
# NULL
#
# $TotalBsmtSF
# NULL
#
# $`1stFlrSF`
# NULL
#
# $`2ndFlrSF`
# NULL
#
# $LowQualFinSF
# NULL
#
# $GrLivArea
# NULL
#
# $BsmtFullBath
# NULL
#
# $BsmtHalfBath
# NULL
#
# $FullBath
# NULL
#
# $HalfBath
# NULL
#
# $BedroomAbvGr
# NULL
#
# $KitchenAbvGr
# NULL
#
# $TotRmsAbvGrd
# NULL
#
# $Fireplaces
# NULL
#
# $GarageYrBlt
# NULL
#
# $GarageCars
# NULL
#
# $GarageArea
# NULL
#
# $WoodDeckSF
# NULL
#
# $OpenPorchSF
# NULL
#
# $EnclosedPorch
# NULL
#
# $`3SsnPorch`
# NULL
#
# $ScreenPorch
# NULL
#
# $PoolArea
# NULL
#
# $MiscVal
# NULL
#
# $MoSold
# NULL
#
# $YrSold
# NULL
#
# $Street
# [1] "Grvl" "Pave"
#
# $LotShape
# [1] "IR1" "IR2" "IR3" "Reg"
#
# $LandContour
# [1] "Bnk" "HLS" "Low" "Lvl"
#
# $LotConfig
# [1] "Corner"  "CulDSac" "FR2"     "FR3"     "Inside"
#
# $LandSlope
# [1] "Gtl" "Mod" "Sev"
#
# $Neighborhood
#  [1] "Blmngtn" "Blueste" "BrDale"  "BrkSide" "ClearCr" "CollgCr" "Crawfor"
#  [8] "Edwards" "Gilbert" "IDOTRR"  "MeadowV" "Mitchel" "NAmes"   "NoRidge"
# [15] "NPkVill" "NridgHt" "NWAmes"  "OldTown" "Sawyer"  "SawyerW" "Somerst"
# [22] "StoneBr" "SWISU"   "Timber"  "Veenker"
#
# $Condition1
# [1] "Artery" "Feedr"  "Norm"   "PosA"   "PosN"   "RRAe"   "RRAn"   "RRNe"
# [9] "RRNn"
#
# $Condition2
# [1] "Artery" "Feedr"  "Norm"   "PosA"   "PosN"   "RRAe"   "RRAn"   "RRNn"
#
# $BldgType
# [1] "1Fam"   "2fmCon" "Duplex" "Twnhs"  "TwnhsE"
#
# $HouseStyle
# [1] "1.5Fin" "1.5Unf" "1Story" "2.5Fin" "2.5Unf" "2Story" "SFoyer" "SLvl"
#
# $RoofStyle
# [1] "Flat"    "Gable"   "Gambrel" "Hip"     "Mansard" "Shed"
#
# $RoofMatl
# [1] "ClyTile" "CompShg" "Membran" "Metal"   "Roll"    "Tar&Grv" "WdShake"
# [8] "WdShngl"
#
# $ExterQual
# [1] "Ex" "Fa" "Gd" "TA"
#
# $ExterCond
# [1] "Ex" "Fa" "Gd" "Po" "TA"
#
# $Heating
# [1] "Floor" "GasA"  "GasW"  "Grav"  "OthW"  "Wall"
#
# $HeatingQC
# [1] "fine" "bad"
#
# $CentralAir
# [1] "N" "Y"
#
# $PavedDrive
# [1] "N" "P" "Y"
#
# $SaleCondition
# [1] "Abnorml" "AdjLand" "Alloca"  "Family"  "Normal"  "Partial"
#
# $MSZoning
# [1] "C (all)" "FV"      "RH"      "RL"      "RM"      "Unknown"
#
# $Utilities
# [1] "AllPub"  "NoSeWa"  "Unknown"
#
# $Exterior1st
#  [1] "AsbShng" "AsphShn" "BrkComm" "BrkFace" "CBlock"  "CemntBd" "HdBoard"
#  [8] "ImStucc" "MetalSd" "Plywood" "Stone"   "Stucco"  "Unknown" "VinylSd"
# [15] "Wd Sdng" "WdShing"
#
# $Exterior2nd
#  [1] "AsbShng" "AsphShn" "Brk Cmn" "BrkFace" "CBlock"  "CmentBd" "HdBoard"
#  [8] "ImStucc" "MetalSd" "Other"   "Plywood" "Stone"   "Stucco"  "Unknown"
# [15] "VinylSd" "Wd Sdng" "Wd Shng"
#
# $MasVnrType
# [1] "BrkCmn"  "BrkFace" "None"    "Stone"   "Unknown"
#
# $BsmtQual
# [1] "great"   "normal"  "unknown"
#
# $BsmtCond
# [1] "Fa"      "Gd"      "Po"      "TA"      "Unknown"
#
# $BsmtExposure
# [1] "Av"      "Gd"      "Mn"      "No"      "Unknown"
#
# $BsmtFinType1
# [1] "ALQ"     "BLQ"     "GLQ"     "LwQ"     "Rec"     "Unf"     "Unknown"
#
# $BsmtFinType2
# [1] "ALQ"     "BLQ"     "GLQ"     "LwQ"     "Rec"     "Unf"     "Unknown"
#
# $KitchenQual
# [1] "Ex"      "Fa"      "Gd"      "TA"      "Unknown"
#
# $Functional
# [1] "Maj1"    "Maj2"    "Min1"    "Min2"    "Mod"     "Sev"     "Typ"
# [8] "Unknown"
#
# $GarageType
# [1] "2Types"  "Attchd"  "Basment" "BuiltIn" "CarPort" "Detchd"  "Unknown"
#
# $GarageFinish
# [1] "Fin"     "RFn"     "Unf"     "Unknown"
#
# $GarageQual
# [1] "fine"    "bad"     "unknown"
#
# $GarageCond
# [1] "fine"    "bad"     "unknown"
#
# $SaleType
#  [1] "COD"     "Con"     "ConLD"   "ConLI"   "ConLw"   "CWD"     "New"
#  [8] "Oth"     "Unknown" "WD"
#
# $MiscFeature
# [1] "Gar2"    "Othr"    "Shed"    "TenC"    "Unknown"

# %%
dim(load.train$combine.columns())
load.train$get.labels()
# Out:
# [1] 1460   73
#      SalePrice Id
# 1    208500     1
# 2    181500     2
# 3    223500     3
# 4    140000     4
# 5    250000     5
# 6    143000     6
# 7    307000     7
# 8    200000     8
# 9    129900     9
# 10   118000    10
# 11   129500    11
# 12   345000    12
# 13   144000    13
# 14   279500    14
# 15   157000    15
# 16   132000    16
# 17   149000    17
# 18    90000    18
# 19   159000    19
# 20   139000    20
# 21   325300    21
# 22   139400    22
# 23   230000    23
# 24   129900    24
# 25   154000    25
# 26   256300    26
# 27   134800    27
# 28   306000    28
# 29   207500    29
# 30    68500    30
# ...  ...       ...
# 1431 192140    1431
# 1432 143750    1432
# 1433  64500    1433
# 1434 186500    1434
# 1435 160000    1435
# 1436 174000    1436
# 1437 120500    1437
# 1438 394617    1438
# 1439 149700    1439
# 1440 197000    1440
# 1441 191000    1441
# 1442 149300    1442
# 1443 310000    1443
# 1444 121000    1444
# 1445 179600    1445
# 1446 129000    1446
# 1447 157900    1447
# 1448 240000    1448
# 1449 112000    1449
# 1450  92000    1450
# 1451 136000    1451
# 1452 287090    1452
# 1453 145000    1453
# 1454  84500    1454
# 1455 185000    1455
# 1456 175000    1456
# 1457 210000    1457
# 1458 266500    1458
# 1459 142125    1459
# 1460 147500    1460
